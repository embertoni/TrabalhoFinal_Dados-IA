# %%
# %pip install pandas
import pandas as pd

# %%
#determinar o caminho do arquivo
df = pd.read_csv("arquivo.csv")
df

# %%
# tirar colunas da tabela
df = df.drop(columns=["coluna1", "coluna2"])
df

# %%
#informações sobre o dataframe
df.info()
#detrminar o uso de memória do dataframe
df.info(memory_usage="deep")

# %%
#quais variaveis estao linkadas as colunas ?
df["coluna1"].unique()

# %%
#quantas vezes cada valor aparece na coluna ?
df["coluna1"].value_counts()

# %%
#substituir os valores da coluna por outros valores
df['coluna'] = df['coluna'].map({ }).astype('bool')

# %%
df.info(memory_usage="deep")

# %%
df["coluna2"].unique()

# %%
df["coluna2"] = df["coluna2"].astype("category")
